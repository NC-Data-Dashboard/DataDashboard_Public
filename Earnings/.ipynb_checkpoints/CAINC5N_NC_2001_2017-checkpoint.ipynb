# %%
## Written and published by Nathan Young, Junior Data Analyst for NC Data Dashboard, November 2019 ##

# %%
# Imports
import pandas as pd
import requests
from io import BytesIO, StringIO
from zipfile import ZipFile

# %%
# Create Backups
''' Must create backups manually!! '''
# Out:
# ' Must create backups manually!! '

# %%
# Load BEA CAINC5N_NC data
response = requests.get('https://apps.bea.gov/regional/zip/CAINC5N.zip')
zip_file = ZipFile(BytesIO(response.content))
files = zip_file.namelist()
with zip_file.open(files[34]) as csvfile:
    df = pd.read_csv(csvfile, encoding='ISO-8859-1', sep=",")

# %%
# Check for non-data fields
df.tail(10)
# Out:
#                                                  GeoFIPS     GeoName  Region  \
# 13225                                            "37199"  Yancey, NC     5.0
# 13226                                            "37199"  Yancey, NC     5.0
# 13227                                            "37199"  Yancey, NC     5.0
# 13228                                            "37199"  Yancey, NC     5.0
# 13229                                            "37199"  Yancey, NC     5.0
# 13230                                            "37199"  Yancey, NC     5.0
# 13231              Note: See the included footnote file.         NaN     NaN
# 13232  CAINC5N: Personal Income by Major Component an...         NaN     NaN
# 13233  Last updated: November 15, 2018-- new statisti...         NaN     NaN
# 13234  Source: U.S. Department of Commerce / Bureau o...         NaN     NaN
#
#       TableName  LineCode IndustryClassification  \
# 13225   CAINC5N    2000.0                    ...
# 13226   CAINC5N    2001.0                    ...
# 13227   CAINC5N    2002.0                    ...
# 13228   CAINC5N    2010.0                    ...
# 13229   CAINC5N    2011.0                    ...
# 13230   CAINC5N    2012.0                    ...
# 13231       NaN       NaN                    NaN
# 13232       NaN       NaN                    NaN
# 13233       NaN       NaN                    NaN
# 13234       NaN       NaN                    NaN
#
#                                    Description                  Unit   2001  \
# 13225    Government and government enterprises  Thousands of dollars  31811
# 13226                         Federal civilian  Thousands of dollars   2992
# 13227                                 Military  Thousands of dollars    652
# 13228                          State and local  Thousands of dollars  28167
# 13229                         State government  Thousands of dollars   5028
# 13230                         Local government  Thousands of dollars  23139
# 13231                                      NaN                   NaN    NaN
# 13232                                      NaN                   NaN    NaN
# 13233                                      NaN                   NaN    NaN
# 13234                                      NaN                   NaN    NaN
#
#         2002  ...   2008   2009   2010   2011   2012   2013   2014   2015  \
# 13225  32905  ...  42767  42039  43069  42119  41528  40990  40590  42793
# 13226   3157  ...   3009   3041   3715   3545   3446   2180   2231   3376
# 13227    881  ...   1622   1768   1687   1633   1480   1389   1294   1208
# 13228  28867  ...  38136  37230  37667  36941  36602  37421  37065  38209
# 13229   5552  ...   6035   6036   5825   5599   5728   5874   5322   5246
# 13230  23315  ...  32101  31194  31842  31342  30874  31547  31743  32963
# 13231    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13232    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13233    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13234    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#         2016   2017
# 13225  50170  51546
# 13226   3278   3204
# 13227   1236   1208
# 13228  45656  47134
# 13229   5539   5556
# 13230  40117  41578
# 13231    NaN    NaN
# 13232    NaN    NaN
# 13233    NaN    NaN
# 13234    NaN    NaN
#
# [10 rows x 25 columns]

# %%
# Remove non-data fields
df_clean = df[:-4]
df_clean.tail(5)
# Out:
#         GeoFIPS     GeoName  Region TableName  LineCode  \
# 13226   "37199"  Yancey, NC     5.0   CAINC5N    2001.0
# 13227   "37199"  Yancey, NC     5.0   CAINC5N    2002.0
# 13228   "37199"  Yancey, NC     5.0   CAINC5N    2010.0
# 13229   "37199"  Yancey, NC     5.0   CAINC5N    2011.0
# 13230   "37199"  Yancey, NC     5.0   CAINC5N    2012.0
#
#       IndustryClassification           Description                  Unit  \
# 13226                    ...      Federal civilian  Thousands of dollars
# 13227                    ...              Military  Thousands of dollars
# 13228                    ...       State and local  Thousands of dollars
# 13229                    ...      State government  Thousands of dollars
# 13230                    ...      Local government  Thousands of dollars
#
#         2001   2002  ...   2008   2009   2010   2011   2012   2013   2014  \
# 13226   2992   3157  ...   3009   3041   3715   3545   3446   2180   2231
# 13227    652    881  ...   1622   1768   1687   1633   1480   1389   1294
# 13228  28167  28867  ...  38136  37230  37667  36941  36602  37421  37065
# 13229   5028   5552  ...   6035   6036   5825   5599   5728   5874   5322
# 13230  23139  23315  ...  32101  31194  31842  31342  30874  31547  31743
#
#         2015   2016   2017
# 13226   3376   3278   3204
# 13227   1208   1236   1208
# 13228  38209  45656  47134
# 13229   5246   5539   5556
# 13230  32963  40117  41578
#
# [5 rows x 25 columns]

# %%
# Save as tab-delimited txt file for export to SSMS
df_clean.to_csv('./Updates/STG_BEA_CAINC5N_NC_2001_2017.txt', sep = '\t')
