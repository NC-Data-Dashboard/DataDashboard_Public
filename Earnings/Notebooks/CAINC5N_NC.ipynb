# %%
import pandas as pd

# %%
'''Must create backups manually at this time!!
Add _BACKUP to the name of the .txt file in Updates and move it to 
 Backups folder before running this script!'''
# Out:
# 'Must create backups manually at this time!!\nAdd _BACKUP to the name of the .txt file in Updates and move it to \n Backups folder before running this script!'

# %%
df = pd.read_csv('./Data/CAINC5N_NC_2001_2017.csv')
df.head()
# Out:
#     GeoFIPS         GeoName  Region TableName  LineCode  \
# 0   "37000"  North Carolina     5.0   CAINC5N      10.0
# 1   "37000"  North Carolina     5.0   CAINC5N      20.0
# 2   "37000"  North Carolina     5.0   CAINC5N      30.0
# 3   "37000"  North Carolina     5.0   CAINC5N      35.0
# 4   "37000"  North Carolina     5.0   CAINC5N      36.0
#
#   IndustryClassification                                        Description  \
# 0                    ...             Personal income (thousands of dollars)
# 1                    ...                            Population (persons) 2/
# 2                    ...               Per capita personal income (dollars)
# 3                    ...                          Earnings by place of work
# 4                    ...   Less: Contributions for government social ins...
#
#                    Unit       2001       2002  ...       2008       2009  \
# 0  Thousands of dollars  228431654  231805733  ...  350372649  337787031
# 1     Number of persons    8210122    8326201  ...    9309449    9449566
# 2               Dollars      27823      27841  ...      37636      35746
# 3  Thousands of dollars  174113335  176206894  ...  257505459  243168101
# 4  Thousands of dollars   20100040   20369137  ...   28278511   27492664
#
#         2010       2011       2012       2013       2014       2015  \
# 0  340764297  354294372  379031187  375057001  397410713  419888909
# 1    9574247    9662940    9755299    9849812    9941160   10041769
# 2      35592      36665      38854      38078      39976      41814
# 3  243762027  247464422  267072169  266760383  280027813  294005281
# 4   27812781   25926513   26956299   31307775   32873914   34556456
#
#         2016       2017
# 0  433766368  454306904
# 1   10156689   10273419
# 2      42707      44222
# 3  303794979  318753696
# 4   35607243   36977394
#
# [5 rows x 25 columns]

# %%
df.to_csv('./Updates/STG_BEA_CAINC5N_NC_2001_2017.txt', sep = '\t')
