# %%
## Written and published by Nathan Young, Junior Data Analyst for NC Data Dashboard, December 2019 ##

# %%
# Imports
import pandas as pd
import requests
from io import BytesIO, StringIO
from zipfile import ZipFile

# %%
# Create Backups
df_backup = pd.read_csv('./Updates/STG_BEA_CAINC5N_NC.txt', encoding = 'ISO-8859-1', sep='\t')
df_backup.to_csv('./Backups/STG_BEA_CAINC5N_NC_BACKUP.txt')

# %%
# Load BEA CAINC5N_NC data
response = requests.get('https://apps.bea.gov/regional/zip/CAINC5N.zip')
zip_file = ZipFile(BytesIO(response.content))
files = zip_file.namelist()
with zip_file.open(files[34]) as csvfile:
    df = pd.read_csv(csvfile, encoding='ISO-8859-1', sep=",")

# %%
# Check for non-data fields
df.tail(10)
# Out:
#                                                  GeoFIPS     GeoName  Region  \
# 13225                                            "37199"  Yancey, NC     5.0
# 13226                                            "37199"  Yancey, NC     5.0
# 13227                                            "37199"  Yancey, NC     5.0
# 13228                                            "37199"  Yancey, NC     5.0
# 13229                                            "37199"  Yancey, NC     5.0
# 13230                                            "37199"  Yancey, NC     5.0
# 13231              Note: See the included footnote file.         NaN     NaN
# 13232  CAINC5N: Personal Income by Major Component an...         NaN     NaN
# 13233  Last updated: November 14, 2019-- new statisti...         NaN     NaN
# 13234  Source: U.S. Department of Commerce / Bureau o...         NaN     NaN
#
#       TableName  LineCode IndustryClassification  \
# 13225   CAINC5N    2000.0                    ...
# 13226   CAINC5N    2001.0                    ...
# 13227   CAINC5N    2002.0                    ...
# 13228   CAINC5N    2010.0                    ...
# 13229   CAINC5N    2011.0                    ...
# 13230   CAINC5N    2012.0                    ...
# 13231       NaN       NaN                    NaN
# 13232       NaN       NaN                    NaN
# 13233       NaN       NaN                    NaN
# 13234       NaN       NaN                    NaN
#
#                                    Description                  Unit   2001  \
# 13225    Government and government enterprises  Thousands of dollars  31811
# 13226                         Federal civilian  Thousands of dollars   2992
# 13227                                 Military  Thousands of dollars    652
# 13228                          State and local  Thousands of dollars  28167
# 13229                         State government  Thousands of dollars   5028
# 13230                         Local government  Thousands of dollars  23139
# 13231                                      NaN                   NaN    NaN
# 13232                                      NaN                   NaN    NaN
# 13233                                      NaN                   NaN    NaN
# 13234                                      NaN                   NaN    NaN
#
#         2002  ...   2009   2010   2011   2012   2013   2014   2015   2016  \
# 13225  32905  ...  42039  43069  42119  41528  40990  40595  42823  50157
# 13226   3157  ...   3041   3715   3545   3446   2180   2227   3371   3270
# 13227    881  ...   1768   1687   1633   1480   1389   1287   1220   1261
# 13228  28867  ...  37230  37667  36941  36602  37421  37081  38232  45626
# 13229   5552  ...   6036   5825   5599   5728   5874   5297   5224   5508
# 13230  23315  ...  31194  31842  31342  30874  31547  31784  33008  40118
# 13231    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13232    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13233    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 13234    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#         2017   2018
# 13225  51335  51005
# 13226   3197   3318
# 13227   1221   1308
# 13228  46917  46379
# 13229   5512   5843
# 13230  41405  40536
# 13231    NaN    NaN
# 13232    NaN    NaN
# 13233    NaN    NaN
# 13234    NaN    NaN
#
# [10 rows x 26 columns]

# %%
# Remove non-data fields
df_clean = df[:-4]
df_clean.tail(5)
# Out:
#         GeoFIPS     GeoName  Region TableName  LineCode  \
# 13226   "37199"  Yancey, NC     5.0   CAINC5N    2001.0
# 13227   "37199"  Yancey, NC     5.0   CAINC5N    2002.0
# 13228   "37199"  Yancey, NC     5.0   CAINC5N    2010.0
# 13229   "37199"  Yancey, NC     5.0   CAINC5N    2011.0
# 13230   "37199"  Yancey, NC     5.0   CAINC5N    2012.0
#
#       IndustryClassification           Description                  Unit  \
# 13226                    ...      Federal civilian  Thousands of dollars
# 13227                    ...              Military  Thousands of dollars
# 13228                    ...       State and local  Thousands of dollars
# 13229                    ...      State government  Thousands of dollars
# 13230                    ...      Local government  Thousands of dollars
#
#         2001   2002  ...   2009   2010   2011   2012   2013   2014   2015  \
# 13226   2992   3157  ...   3041   3715   3545   3446   2180   2227   3371
# 13227    652    881  ...   1768   1687   1633   1480   1389   1287   1220
# 13228  28167  28867  ...  37230  37667  36941  36602  37421  37081  38232
# 13229   5028   5552  ...   6036   5825   5599   5728   5874   5297   5224
# 13230  23139  23315  ...  31194  31842  31342  30874  31547  31784  33008
#
#         2016   2017   2018
# 13226   3270   3197   3318
# 13227   1261   1221   1308
# 13228  45626  46917  46379
# 13229   5508   5512   5843
# 13230  40118  41405  40536
#
# [5 rows x 26 columns]

# %%
# Set GeoFIPS as Index
df_clean.set_index(df_clean['GeoFIPS'], inplace = True)
df_clean.head(2)
# Out:
#            GeoFIPS         GeoName  Region TableName  LineCode  \
# GeoFIPS
#  "37000"   "37000"  North Carolina     5.0   CAINC5N      10.0
#  "37000"   "37000"  North Carolina     5.0   CAINC5N      20.0
#
#          IndustryClassification                             Description  \
# GeoFIPS
#  "37000"                    ...  Personal income (thousands of dollars)
#  "37000"                    ...                 Population (persons) 2/
#
#                           Unit       2001       2002  ...       2009  \
# GeoFIPS                                               ...
#  "37000"  Thousands of dollars  228879962  232267281  ...  338315713
#  "37000"     Number of persons    8210122    8326201  ...    9449566
#
#                2010       2011       2012       2013       2014       2015  \
# GeoFIPS
#  "37000"  341627602  355052267  379925288  376023857  397995923  419891523
#  "37000"    9574293    9656754    9749123    9843599    9933944   10033079
#
#                2016       2017       2018
# GeoFIPS
#  "37000"  433195584  453769026  478861557
#  "37000"   10156679   10270800   10383620
#
# [2 rows x 26 columns]

# %%
# Drop GeoFIPS column
df_clean.drop('GeoFIPS', axis = 1, inplace = True)
df_clean.head(2)
# Out:
#                  GeoName  Region TableName  LineCode IndustryClassification  \
# GeoFIPS
#  "37000"  North Carolina     5.0   CAINC5N      10.0                    ...
#  "37000"  North Carolina     5.0   CAINC5N      20.0                    ...
#
#                                      Description                  Unit  \
# GeoFIPS
#  "37000"  Personal income (thousands of dollars)  Thousands of dollars
#  "37000"                 Population (persons) 2/     Number of persons
#
#                2001       2002       2003  ...       2009       2010  \
# GeoFIPS                                    ...
#  "37000"  228879962  232267281  241625829  ...  338315713  341627602
#  "37000"    8210122    8326201    8422501  ...    9449566    9574293
#
#                2011       2012       2013       2014       2015       2016  \
# GeoFIPS
#  "37000"  355052267  379925288  376023857  397995923  419891523  433195584
#  "37000"    9656754    9749123    9843599    9933944   10033079   10156679
#
#                2017       2018
# GeoFIPS
#  "37000"  453769026  478861557
#  "37000"   10270800   10383620
#
# [2 rows x 25 columns]

# %%
# Save as tab-delimited txt file for export to SSMS
df_clean.to_csv('./Updates/STG_BEA_CAINC5N_NC.txt', sep = '\t')
