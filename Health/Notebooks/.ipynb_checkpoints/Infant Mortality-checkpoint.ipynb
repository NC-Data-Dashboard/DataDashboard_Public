# %%
import pandas as pd

# %%
df = pd.read_excel('https://datacenter.kidscount.org/rawdata.axd?ind=9977&loc=35', encoding = 'ISO-8859-1')
df
# Out:
#      LocationType        Location                           Race  TimeFrame  \
# 0           State  North Carolina             Non-Hispanic White       2013
# 1           State  North Carolina  Non-Hispanic African American       2013
# 2           State  North Carolina   Non-Hispanic American Indian       2013
# 3           State  North Carolina             Other Non-Hispanic       2013
# 4           State  North Carolina                       Hispanic       2013
# ...           ...             ...                            ...        ...
# 6055       County          Yancey             Other Non-Hispanic       2017
# 6056       County          Yancey                       Hispanic       2017
# 6057       County          Yancey                       Hispanic       2017
# 6058       County          Yancey                          Total       2017
# 6059       County          Yancey                          Total       2017
#
#      DataFormat   Data
# 0        Number  366.0
# ...

# %%
df.to_csv('../Updates/STG_Health_Infant_Mortality.txt', sep = '\t')
