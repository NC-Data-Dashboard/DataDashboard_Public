# %%
import pandas as pd

# %%
df = pd.read_csv('https://injuryfreenc.shinyapps.io/OpioidActionPlan/_w_31be441b/session/a4b21297919ad5ae607a8e350984e368/download/download_all_data?w=31be441b')

# %%
df
# Out:
#           place  year  quarter  pop  unint_opioid_deaths_n opioid  \
# 0      Alamance  1999        1  NaN                    0.0    NaN
# 1     Alexander  1999        1  NaN                    0.0    NaN
# 2     Alleghany  1999        1  NaN                    0.0    NaN
# 3         Anson  1999        1  NaN                    0.0    NaN
# 4          Ashe  1999        1  NaN                    0.0    NaN
# ...         ...   ...      ...  ...                    ...    ...
# 9298    UNKNOWN  2017        4  NaN                    NaN    NaN
# 9299    UNKNOWN  2018        1  NaN                    NaN    NaN
# 9300    UNKNOWN  2018        2  NaN                    NaN    NaN
# 9301    UNKNOWN  2018        3  NaN                    NaN    NaN
# 9302    UNKNOWN  2018        4  NaN                    NaN    NaN
#
#       multiple_episodes_n  pills_n  patients_90mme_pct  \
# 0                     NaN      NaN                 NaN
# 1                     NaN      NaN                 NaN
# ...
