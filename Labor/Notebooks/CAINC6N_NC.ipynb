# %%
## Written and published by Nathan Young, Junior Data Analyst for NC Data Dashboard, December 2019 ##

# %%
# Imports
import pandas as pd
import requests
from io import BytesIO, StringIO
from zipfile import ZipFile

# %%
# Create Backups
#df_backup = pd.read_csv('./Updates/STG_BEA_CAINC6N_NC.txt', 
                        #encoding = 'ISO-8859-1', 
                        #sep = "\t")
#df_backup.to_csv('./Backups/STG_BEA_CAINC6N_NC_BACKUP.txt')

# %%
# Load BEA CAINC6N_NC data
response = requests.get('https://apps.bea.gov/regional/zip/CAINC6N.zip')
zip_file = ZipFile(BytesIO(response.content))
files = zip_file.namelist()
with zip_file.open(files[34]) as csvfile:
    df = pd.read_csv(csvfile, encoding='ISO-8859-1', sep=",")

# %%
# Check for non-data fields
df.tail(10)
# Out:
#                                                  GeoFIPS     GeoName  Region  \
# 12012                                            "37199"  Yancey, NC     5.0
# 12013                                            "37199"  Yancey, NC     5.0
# 12014                                            "37199"  Yancey, NC     5.0
# 12015                                            "37199"  Yancey, NC     5.0
# 12016                                            "37199"  Yancey, NC     5.0
# 12017                                            "37199"  Yancey, NC     5.0
# 12018                                            "37199"  Yancey, NC     5.0
# 12019              Note: See the included footnote file.         NaN     NaN
# 12020  Last updated: November 14, 2019-- new statisti...         NaN     NaN
# 12021  Source: U.S. Department of Commerce / Bureau o...         NaN     NaN
#
#       TableName  LineCode IndustryClassification  \
# 12012   CAINC6N    1904.0                    814
# 12013   CAINC6N    2000.0                    ...
# 12014   CAINC6N    2001.0                    ...
# 12015   CAINC6N    2002.0                    ...
# 12016   CAINC6N    2010.0                    ...
# 12017   CAINC6N    2011.0                    ...
# 12018   CAINC6N    2012.0                    ...
# 12019       NaN       NaN                    NaN
# 12020       NaN       NaN                    NaN
# 12021       NaN       NaN                    NaN
#
#                                    Description                  Unit   2001  \
# 12012                       Private households  Thousands of dollars    664
# 12013    Government and government enterprises  Thousands of dollars  31811
# 12014                         Federal civilian  Thousands of dollars   2992
# 12015                                 Military  Thousands of dollars    652
# 12016                          State and local  Thousands of dollars  28167
# 12017                         State government  Thousands of dollars   5028
# 12018                         Local government  Thousands of dollars  23139
# 12019                                      NaN                   NaN    NaN
# 12020                                      NaN                   NaN    NaN
# 12021                                      NaN                   NaN    NaN
#
#         2002  ...   2009   2010   2011   2012   2013   2014   2015   2016  \
# 12012    639  ...    752    654    684    (D)    (D)    (D)    (D)    (D)
# 12013  32905  ...  42039  43069  42119  41528  40990  40595  42823  50157
# 12014   3157  ...   3041   3715   3545   3446   2180   2227   3371   3270
# 12015    881  ...   1768   1687   1633   1480   1389   1287   1220   1261
# 12016  28867  ...  37230  37667  36941  36602  37421  37081  38232  45626
# 12017   5552  ...   6036   5825   5599   5728   5874   5297   5224   5508
# 12018  23315  ...  31194  31842  31342  30874  31547  31784  33008  40118
# 12019    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12020    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 12021    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#         2017   2018
# 12012    (D)    (D)
# 12013  51335  51005
# 12014   3197   3318
# 12015   1221   1308
# 12016  46917  46379
# 12017   5512   5843
# 12018  41405  40536
# 12019    NaN    NaN
# 12020    NaN    NaN
# 12021    NaN    NaN
#
# [10 rows x 26 columns]

# %%
# Remove non-data fields
df_clean = df[:-3]
df_clean.tail(5)
# Out:
#         GeoFIPS     GeoName  Region TableName  LineCode  \
# 12014   "37199"  Yancey, NC     5.0   CAINC6N    2001.0
# 12015   "37199"  Yancey, NC     5.0   CAINC6N    2002.0
# 12016   "37199"  Yancey, NC     5.0   CAINC6N    2010.0
# 12017   "37199"  Yancey, NC     5.0   CAINC6N    2011.0
# 12018   "37199"  Yancey, NC     5.0   CAINC6N    2012.0
#
#       IndustryClassification           Description                  Unit  \
# 12014                    ...      Federal civilian  Thousands of dollars
# 12015                    ...              Military  Thousands of dollars
# 12016                    ...       State and local  Thousands of dollars
# 12017                    ...      State government  Thousands of dollars
# 12018                    ...      Local government  Thousands of dollars
#
#         2001   2002  ...   2009   2010   2011   2012   2013   2014   2015  \
# 12014   2992   3157  ...   3041   3715   3545   3446   2180   2227   3371
# 12015    652    881  ...   1768   1687   1633   1480   1389   1287   1220
# 12016  28167  28867  ...  37230  37667  36941  36602  37421  37081  38232
# 12017   5028   5552  ...   6036   5825   5599   5728   5874   5297   5224
# 12018  23139  23315  ...  31194  31842  31342  30874  31547  31784  33008
#
#         2016   2017   2018
# 12014   3270   3197   3318
# 12015   1261   1221   1308
# 12016  45626  46917  46379
# 12017   5508   5512   5843
# 12018  40118  41405  40536
#
# [5 rows x 26 columns]

# %%
# Set GeoFIPS as Index
df_clean.set_index(df_clean['GeoFIPS'], inplace = True)
df_clean.head()
# Out:
#            GeoFIPS         GeoName  Region TableName  LineCode  \
# GeoFIPS
#  "37000"   "37000"  North Carolina     5.0   CAINC6N       1.0
#  "37000"   "37000"  North Carolina     5.0   CAINC6N       5.0
#  "37000"   "37000"  North Carolina     5.0   CAINC6N       6.0
#  "37000"   "37000"  North Carolina     5.0   CAINC6N       7.0
#  "37000"   "37000"  North Carolina     5.0   CAINC6N       8.0
#
#          IndustryClassification  \
# GeoFIPS
#  "37000"                    ...
#  "37000"                    ...
#  "37000"                    ...
#  "37000"                    ...
#  "37000"                    ...
#
#                                                 Description  \
# GeoFIPS
#  "37000"  Compensation of employees (thousands of dollar...
#  "37000"                                 Wages and salaries
#  "37000"                  Supplements to wages and salaries
#  "37000"    Employer contributions for employee pension ...
#  "37000"    Employer contributions for government social...
#
#                           Unit       2001       2002  ...       2009  \
# GeoFIPS                                               ...
#  "37000"  Thousands of dollars  160371299  162957779  ...  211454924
#  "37000"  Thousands of dollars  132002644  133601815  ...  169548458
#  "37000"  Thousands of dollars   28368655   29355964  ...   41906466
#  "37000"  Thousands of dollars   18671663   19657908  ...   28774662
#  "37000"  Thousands of dollars    9696992    9698056  ...   13131804
#
#                2010       2011       2012       2013       2014       2015  \
# GeoFIPS
#  "37000"  216515016  222527671  232370554  237874021  250729957  263501208
#  "37000"  173519379  179966208  187090787  192266678  201605023  212899864
#  "37000"   42995637   42561463   45279767   45607343   49124934   50601344
#  "37000"   29762841   28598403   30721367   30617687   33329846   34054582
#  "37000"   13232796   13963060   14558400   14989656   15795088   16546762
#
#                2016       2017       2018
# GeoFIPS
#  "37000"  271845644  283403091  298666892
#  "37000"  221474327  232229403  245399095
#  "37000"   50371317   51173688   53267797
#  "37000"   33680781   34168208   36123442
#  "37000"   16690536   17005480   17144355
#
# [5 rows x 26 columns]

# %%
# Drop GeoFIPS column 
df_clean.drop('GeoFIPS', axis = 1, inplace = True)
df_clean
# Out:
# c:\users\natha\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                  GeoName  Region TableName  LineCode IndustryClassification  \
# GeoFIPS
#  "37000"  North Carolina     5.0   CAINC6N       1.0                    ...
#  "37000"  North Carolina     5.0   CAINC6N       5.0                    ...
#  "37000"  North Carolina     5.0   CAINC6N       6.0                    ...
#  "37000"  North Carolina     5.0   CAINC6N       7.0                    ...
#  "37000"  North Carolina     5.0   CAINC6N       8.0                    ...
# ...                  ...     ...       ...       ...                    ...
#  "37199"      Yancey, NC     5.0   CAINC6N    2001.0                    ...
#  "37199"      Yancey, NC     5.0   CAINC6N    2002.0                    ...
#  "37199"      Yancey, NC     5.0   CAINC6N    2010.0                    ...
#  "37199"      Yancey, NC     5.0   CAINC6N    2011.0                    ...
#  "37199"      Yancey, NC     5.0   CAINC6N    2012.0                    ...
#
#                                                 Description  \
# GeoFIPS
#  "37000"  Compensation of employees (thousands of dollar...
#  "37000"                                 Wages and salaries
#  "37000"                  Supplements to wages and salaries
#  "37000"    Employer contributions for employee pension ...
#  "37000"    Employer contributions for government social...
# ...                                                     ...
#  "37199"                                   Federal civilian
#  "37199"                                           Military
#  "37199"                                    State and local
#  "37199"                                   State government
#  "37199"                                   Local government
#
#                           Unit       2001       2002       2003  ...  \
# GeoFIPS                                                          ...
#  "37000"  Thousands of dollars  160371299  162957779  168340289  ...
#  "37000"  Thousands of dollars  132002644  133601815  136786159  ...
#  "37000"  Thousands of dollars   28368655   29355964   31554130  ...
#  "37000"  Thousands of dollars   18671663   19657908   21121291  ...
#  "37000"  Thousands of dollars    9696992    9698056   10432839  ...
# ...                        ...        ...        ...        ...  ...
#  "37199"  Thousands of dollars       2992       3157       3277  ...
#  "37199"  Thousands of dollars        652        881       1302  ...
#  "37199"  Thousands of dollars      28167      28867      28799  ...
#  "37199"  Thousands of dollars       5028       5552       4710  ...
#  "37199"  Thousands of dollars      23139      23315      24089  ...
#
#                2009       2010       2011       2012       2013       2014  \
# GeoFIPS
#  "37000"  211454924  216515016  222527671  232370554  237874021  250729957
#  "37000"  169548458  173519379  179966208  187090787  192266678  201605023
#  "37000"   41906466   42995637   42561463   45279767   45607343   49124934
#  "37000"   28774662   29762841   28598403   30721367   30617687   33329846
#  "37000"   13131804   13232796   13963060   14558400   14989656   15795088
# ...             ...        ...        ...        ...        ...        ...
#  "37199"       3041       3715       3545       3446       2180       2227
#  "37199"       1768       1687       1633       1480       1389       1287
#  "37199"      37230      37667      36941      36602      37421      37081
#  "37199"       6036       5825       5599       5728       5874       5297
#  "37199"      31194      31842      31342      30874      31547      31784
#
#                2015       2016       2017       2018
# GeoFIPS
#  "37000"  263501208  271845644  283403091  298666892
#  "37000"  212899864  221474327  232229403  245399095
#  "37000"   50601344   50371317   51173688   53267797
#  "37000"   34054582   33680781   34168208   36123442
#  "37000"   16546762   16690536   17005480   17144355
# ...             ...        ...        ...        ...
#  "37199"       3371       3270       3197       3318
#  "37199"       1220       1261       1221       1308
#  "37199"      38232      45626      46917      46379
#  "37199"       5224       5508       5512       5843
#  "37199"      33008      40118      41405      40536
#
# [12019 rows x 25 columns]

# %%
# Save as tab-delimited txt file for export to SSMS
#df_clean.to_csv('./Updates/STG_BEA_CAINC6N_NC.txt', sep = '\t')
