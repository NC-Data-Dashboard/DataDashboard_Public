# %%
## Written and published by Nathan Young, Junior Data Analyst for NC Data Dashboard, December 2019 ##

# %%
#Imports
import pandas as pd

# %%
# Create Backups
df_backup = pd.read_csv('./Updates/STG_ZLLW_County_MedianListingPrice_AllHomes.txt')
df_backup.to_csv('./Backups/STG_ZLLW_County_MedianListingPrice_AllHomes_BACKUP.txt')

# %%
#Load Land data
df_mlp = pd.read_csv('http://files.zillowstatic.com/research/public/County/County_MedianListingPrice_AllHomes.csv',
                     encoding='ISO-8859-1')

#Display table to ensure data loaded correctly
df_mlp.head()
# Out:
#            RegionName State                             Metro  StateCodeFIPS  \
# 0  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim              6
# 1         Cook County    IL          Chicago-Naperville-Elgin             17
# 2       Harris County    TX  Houston-The Woodlands-Sugar Land             48
# 3     Maricopa County    AZ           Phoenix-Mesa-Scottsdale              4
# 4    San Diego County    CA                San Diego-Carlsbad              6
#
#    MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 0                 37         1  399000.0  389000.0  399000.0  398884.0  ...
# 1                 31         2  244900.0  249000.0  249000.0  249000.0  ...
# 2                201         3  149900.0  152800.0  154705.0  154900.0  ...
# 3                 13         4  179900.0  176000.0  174900.0  169900.0  ...
# 4                 73         5  399000.0  399000.0  399500.0  399990.0  ...
#
#     2019-01   2019-02   2019-03   2019-04   2019-05   2019-06   2019-07  \
# 0  649900.0  650000.0  665000.0  675000.0  679000.0  689000.0  695000.0
# 1  280000.0  289900.0  299000.0  300000.0  300000.0  299900.0  299000.0
# 2  276900.0  278950.0  279900.0  284999.0  282990.0  280000.0  278000.0
# 3  310000.0  310000.0  315000.0  318850.0  319000.0  319900.0  317000.0
# 4  635000.0  639000.0  643900.0  650000.0  659900.0  655995.0  649990.0
#
#     2019-08   2019-09   2019-10
# 0  689000.0  689000.0  690000.0
# 1  293000.0  290000.0  288000.0
# 2  274990.0  274900.0  270720.0
# 3  315000.0  319000.0  319900.0
# 4  650000.0  657950.0  649900.0
#
# [5 rows x 124 columns]

# %%
#Filter data to NC
filter1 = df_mlp['State'] == "NC"
df_mlp_nc = df_mlp[filter1]

#Check to ensure filter worked
df_mlp_nc.head(5)
# Out:
#              RegionName State                       Metro  StateCodeFIPS  \
# 48   Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# 55          Wake County    NC                     Raleigh             37
# 134     Guilford County    NC       Greensboro-High Point             37
# 183      Forsyth County    NC               Winston-Salem             37
# 198   Cumberland County    NC                Fayetteville             37
#
#      MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 48                 119        49  189900.0  194500.0  190000.0  194000.0  ...
# 55                 183        56  248000.0  245000.0  239900.0  239994.5  ...
# 134                 81       135  159900.0  159900.0  159900.0  159900.0  ...
# 183                 67       184  154900.0  156800.0  159900.0  159900.0  ...
# 198                 51       199       NaN       NaN       NaN       NaN  ...
#
#       2019-01   2019-02   2019-03   2019-04   2019-05   2019-06   2019-07  \
# 48   312000.0  318995.0  318005.0  324999.0  321900.0  320000.0  318854.0
# 55   345000.0  345000.0  349000.0  352900.0  350000.0  350000.0  350000.0
# 134  194900.0  196700.0  208000.0  212900.0  214000.0  214189.5  214900.0
# 183  198500.0  200000.0  215000.0  224900.0  219900.0  225000.0  227400.0
# 198  155000.0  163000.0  165000.0  171500.0  169250.0  168981.0  167900.0
#
#       2019-08   2019-09   2019-10
# 48   314994.5  315000.0  315000.0
# 55   350000.0  350000.0  349900.0
# 134  207900.0  209500.0  214900.0
# 183  220000.0  217200.0  220000.0
# 198  169000.0  163000.0  160900.0
#
# [5 rows x 124 columns]

# %%
#View data types of dataframe
df_mlp_nc.dtypes
# Out:
# RegionName            object
# State                 object
# Metro                 object
# StateCodeFIPS          int64
# MunicipalCodeFIPS      int64
#                       ...
# 2019-06              float64
# 2019-07              float64
# 2019-08              float64
# 2019-09              float64
# 2019-10              float64
# Length: 124, dtype: object

# %%
#Change MunicipalCodeFIPS dtype to add leading 0's
df_mlp_nc.loc[ :, 'MunicipalCodeFIPS'] = df_mlp_nc['MunicipalCodeFIPS'].astype(str)
df_mlp_nc.dtypes
# Out:
# RegionName            object
# State                 object
# Metro                 object
# StateCodeFIPS          int64
# MunicipalCodeFIPS     object
#                       ...
# 2019-06              float64
# 2019-07              float64
# 2019-08              float64
# 2019-09              float64
# 2019-10              float64
# Length: 124, dtype: object

# %%
#Add leading 0's and check to ensure they were added
df_mlp_nc.loc[ :, 'MunicipalCodeFIPS'] = df_mlp_nc['MunicipalCodeFIPS'].str.zfill(3)
df_mlp_nc.head(5)
# Out:
#              RegionName State                       Metro  StateCodeFIPS  \
# 48   Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# 55          Wake County    NC                     Raleigh             37
# 134     Guilford County    NC       Greensboro-High Point             37
# 183      Forsyth County    NC               Winston-Salem             37
# 198   Cumberland County    NC                Fayetteville             37
#
#     MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 48                119        49  189900.0  194500.0  190000.0  194000.0  ...
# 55                183        56  248000.0  245000.0  239900.0  239994.5  ...
# 134               081       135  159900.0  159900.0  159900.0  159900.0  ...
# 183               067       184  154900.0  156800.0  159900.0  159900.0  ...
# 198               051       199       NaN       NaN       NaN       NaN  ...
#
#       2019-01   2019-02   2019-03   2019-04   2019-05   2019-06   2019-07  \
# 48   312000.0  318995.0  318005.0  324999.0  321900.0  320000.0  318854.0
# 55   345000.0  345000.0  349000.0  352900.0  350000.0  350000.0  350000.0
# 134  194900.0  196700.0  208000.0  212900.0  214000.0  214189.5  214900.0
# 183  198500.0  200000.0  215000.0  224900.0  219900.0  225000.0  227400.0
# 198  155000.0  163000.0  165000.0  171500.0  169250.0  168981.0  167900.0
#
#       2019-08   2019-09   2019-10
# 48   314994.5  315000.0  315000.0
# 55   350000.0  350000.0  349900.0
# 134  207900.0  209500.0  214900.0
# 183  220000.0  217200.0  220000.0
# 198  169000.0  163000.0  160900.0
#
# [5 rows x 124 columns]

# %%
# Set Index to Region Name
df_mlp_nc.set_index(df_mlp_nc['RegionName'], inplace = True)
df_mlp_nc
# Out:
#                             RegionName State                       Metro  \
# RegionName
# Mecklenburg County  Mecklenburg County    NC  Charlotte-Concord-Gastonia
# Wake County                Wake County    NC                     Raleigh
# Guilford County        Guilford County    NC       Greensboro-High Point
# Forsyth County          Forsyth County    NC               Winston-Salem
# Cumberland County    Cumberland County    NC                Fayetteville
# ...                                ...   ...                         ...
# Alleghany County      Alleghany County    NC                         NaN
# Clay County                Clay County    NC                         NaN
# Camden County            Camden County    NC              Elizabeth City
# Graham County            Graham County    NC                         NaN
# Hyde County                Hyde County    NC                         NaN
#
#                     StateCodeFIPS MunicipalCodeFIPS  SizeRank   2010-01  \
# RegionName
# Mecklenburg County             37               119        49  189900.0
# Wake County                    37               183        56  248000.0
# Guilford County                37               081       135  159900.0
# Forsyth County                 37               067       184  154900.0
# Cumberland County              37               051       199       NaN
# ...                           ...               ...       ...       ...
# Alleghany County               37               005      2088  229000.0
# Clay County                    37               043      2112  239800.0
# Camden County                  37               029      2134  275000.0
# Graham County                  37               075      2175  302450.0
# Hyde County                    37               095      2256       NaN
#
#                      2010-02   2010-03   2010-04  ...   2019-01   2019-02  \
# RegionName                                        ...
# Mecklenburg County  194500.0  190000.0  194000.0  ...  312000.0  318995.0
# Wake County         245000.0  239900.0  239994.5  ...  345000.0  345000.0
# Guilford County     159900.0  159900.0  159900.0  ...  194900.0  196700.0
# Forsyth County      156800.0  159900.0  159900.0  ...  198500.0  200000.0
# Cumberland County        NaN       NaN       NaN  ...  155000.0  163000.0
# ...                      ...       ...       ...  ...       ...       ...
# Alleghany County    227450.0  225900.0  235250.0  ...  229900.0  236000.0
# Clay County         239000.0  239000.0  239900.0  ...  249450.0  249000.0
# Camden County       274900.0  259900.0  259900.0  ...  274950.0  297900.0
# Graham County       289000.0  289000.0  272200.0  ...  259000.0  264000.0
# Hyde County              NaN       NaN       NaN  ...  339000.0  364900.0
#
#                      2019-03   2019-04   2019-05   2019-06   2019-07  \
# RegionName
# Mecklenburg County  318005.0  324999.0  321900.0  320000.0  318854.0
# Wake County         349000.0  352900.0  350000.0  350000.0  350000.0
# Guilford County     208000.0  212900.0  214000.0  214189.5  214900.0
# Forsyth County      215000.0  224900.0  219900.0  225000.0  227400.0
# Cumberland County   165000.0  171500.0  169250.0  168981.0  167900.0
# ...                      ...       ...       ...       ...       ...
# Alleghany County    229000.0  237000.0  238000.0  244250.0  249000.0
# Clay County         249949.5  251000.0  250000.0  259000.0  259900.0
# Camden County       289900.0  285450.0  285900.0  279900.0  285900.0
# Graham County       269000.0  263000.0  249000.0  239000.0  239000.0
# Hyde County         350000.0  354950.0  364950.0  359900.0  365000.0
#
#                      2019-08   2019-09   2019-10
# RegionName
# Mecklenburg County  314994.5  315000.0  315000.0
# Wake County         350000.0  350000.0  349900.0
# Guilford County     207900.0  209500.0  214900.0
# Forsyth County      220000.0  217200.0  220000.0
# Cumberland County   169000.0  163000.0  160900.0
# ...                      ...       ...       ...
# Alleghany County    248250.0  237000.0  239000.0
# Clay County         258500.0  264950.0  258950.0
# Camden County       289000.0  289000.0  289900.0
# Graham County       252000.0  250000.0  249000.0
# Hyde County         365000.0  350000.0  345000.0
#
# [88 rows x 124 columns]

# %%
# Drop Region Name column
df_mlp_nc.drop('RegionName', axis = 1, inplace = True)
df_mlp_nc
# Out:
#                    State                       Metro  StateCodeFIPS  \
# RegionName
# Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# Wake County           NC                     Raleigh             37
# Guilford County       NC       Greensboro-High Point             37
# Forsyth County        NC               Winston-Salem             37
# Cumberland County     NC                Fayetteville             37
# ...                  ...                         ...            ...
# Alleghany County      NC                         NaN             37
# Clay County           NC                         NaN             37
# Camden County         NC              Elizabeth City             37
# Graham County         NC                         NaN             37
# Hyde County           NC                         NaN             37
#
#                    MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03  \
# RegionName
# Mecklenburg County               119        49  189900.0  194500.0  190000.0
# Wake County                      183        56  248000.0  245000.0  239900.0
# Guilford County                  081       135  159900.0  159900.0  159900.0
# Forsyth County                   067       184  154900.0  156800.0  159900.0
# Cumberland County                051       199       NaN       NaN       NaN
# ...                              ...       ...       ...       ...       ...
# Alleghany County                 005      2088  229000.0  227450.0  225900.0
# Clay County                      043      2112  239800.0  239000.0  239000.0
# Camden County                    029      2134  275000.0  274900.0  259900.0
# Graham County                    075      2175  302450.0  289000.0  289000.0
# Hyde County                      095      2256       NaN       NaN       NaN
#
#                      2010-04   2010-05  ...   2019-01   2019-02   2019-03  \
# RegionName                              ...
# Mecklenburg County  194000.0  190000.0  ...  312000.0  318995.0  318005.0
# Wake County         239994.5  244900.0  ...  345000.0  345000.0  349000.0
# Guilford County     159900.0  159900.0  ...  194900.0  196700.0  208000.0
# Forsyth County      159900.0  158354.0  ...  198500.0  200000.0  215000.0
# Cumberland County        NaN       NaN  ...  155000.0  163000.0  165000.0
# ...                      ...       ...  ...       ...       ...       ...
# Alleghany County    235250.0  229900.0  ...  229900.0  236000.0  229000.0
# Clay County         239900.0  239900.0  ...  249450.0  249000.0  249949.5
# Camden County       259900.0  250000.0  ...  274950.0  297900.0  289900.0
# Graham County       272200.0  269900.0  ...  259000.0  264000.0  269000.0
# Hyde County              NaN       NaN  ...  339000.0  364900.0  350000.0
#
#                      2019-04   2019-05   2019-06   2019-07   2019-08  \
# RegionName
# Mecklenburg County  324999.0  321900.0  320000.0  318854.0  314994.5
# Wake County         352900.0  350000.0  350000.0  350000.0  350000.0
# Guilford County     212900.0  214000.0  214189.5  214900.0  207900.0
# Forsyth County      224900.0  219900.0  225000.0  227400.0  220000.0
# Cumberland County   171500.0  169250.0  168981.0  167900.0  169000.0
# ...                      ...       ...       ...       ...       ...
# Alleghany County    237000.0  238000.0  244250.0  249000.0  248250.0
# Clay County         251000.0  250000.0  259000.0  259900.0  258500.0
# Camden County       285450.0  285900.0  279900.0  285900.0  289000.0
# Graham County       263000.0  249000.0  239000.0  239000.0  252000.0
# Hyde County         354950.0  364950.0  359900.0  365000.0  365000.0
#
#                      2019-09   2019-10
# RegionName
# Mecklenburg County  315000.0  315000.0
# Wake County         350000.0  349900.0
# Guilford County     209500.0  214900.0
# Forsyth County      217200.0  220000.0
# Cumberland County   163000.0  160900.0
# ...                      ...       ...
# Alleghany County    237000.0  239000.0
# Clay County         264950.0  258950.0
# Camden County       289000.0  289900.0
# Graham County       250000.0  249000.0
# Hyde County         350000.0  345000.0
#
# [88 rows x 123 columns]

# %%
#Save to csv file for export in Excel
df_mlp_nc.to_csv('./Updates/STG_ZLLW_County_MedianListingPrice_AllHomes.txt', sep ='\t')
