# %%
## Written and published by Nathan Young, Junior Data Analyst for NC Data Dashboard, December 2019 ##

# %%
#Imports
import pandas as pd

# %%
# Create backups
df_backup = pd.read_csv('./Updates/STG_ZLLW_County_MedianValuePerSqft_AllHomes.txt')
df_backup.to_csv('./Backups/STG_ZLLW_County_MedianValuePerSqft_AllHomes_BACKUP.txt')

# %%
#Load Land data
df_mvsf = pd.read_csv('http://files.zillowstatic.com/research/public/County/County_MedianValuePerSqft_AllHomes.csv', 
                      encoding='ISO-8859-1')

#Display table to ensure data loaded correctly
df_mvsf.head()
# Out:
#    RegionID          RegionName State                             Metro  \
# 0      3101  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim
# 1       139         Cook County    IL          Chicago-Naperville-Elgin
# 2      1090       Harris County    TX  Houston-The Woodlands-Sugar Land
# 3      2402     Maricopa County    AZ           Phoenix-Mesa-Scottsdale
# 4      2841    San Diego County    CA                San Diego-Carlsbad
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  ...  \
# 0              6                 37         1    113.0    113.0    113.0  ...
# 1             17                 31         2    104.0    105.0    105.0  ...
# 2             48                201         3     51.0     51.0     51.0  ...
# 3              4                 13         4     62.0     62.0     62.0  ...
# 4              6                 73         5    104.0    104.0    104.0  ...
#
#    2018-12  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  2019-07  \
# 0      427      429      430      429      429      429      429      429
# 1      168      169      170      171      170      169      169      169
# 2       99      100      101      101      100      101      101      102
# 3      158      159      161      161      161      161      161      162
# 4      375      374      375      375      375      376      376      376
#
#    2019-08  2019-09
# 0      430      431
# 1      168      169
# 2      102      103
# 3      163      164
# 4      376      377
#
# [5 rows x 289 columns]

# %%
#Filter data to NC
filter1 = df_mvsf['State'] == "NC"
df_mvsf_nc = df_mvsf[filter1]

#Check to ensure filter worked
df_mvsf_nc.head(5)
# Out:
#      RegionID          RegionName State                       Metro  \
# 48       3102  Mecklenburg County    NC  Charlotte-Concord-Gastonia
# 55        324         Wake County    NC                     Raleigh
# 134      2312     Guilford County    NC       Greensboro-High Point
# 180      1712      Forsyth County    NC               Winston-Salem
# 194      2912   Cumberland County    NC                Fayetteville
#
#      StateCodeFIPS  MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  \
# 48              37                119        49     67.0     67.0     67.0
# 55              37                183        56     78.0     78.0     78.0
# 134             37                 81       135     68.0     67.0     65.0
# 180             37                 67       181     59.0     59.0     60.0
# 194             37                 51       195     53.0     54.0     54.0
#
#      ...  2018-12  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  \
# 48   ...      129      130      131      131      131      131      131
# 55   ...      143      144      145      145      145      145      145
# 134  ...       93       93       94       94       95       95       95
# 180  ...       95       94       95       96       97       98       98
# 194  ...       76       77       77       77       77       77       77
#
#      2019-07  2019-08  2019-09
# 48       131      132      133
# 55       145      146      147
# 134       96       96       96
# 180       98       99      100
# 194       78       78       78
#
# [5 rows x 289 columns]

# %%
#View data types of dataframe
df_mvsf_nc.dtypes
# Out:
# RegionID          int64
# RegionName       object
# State            object
# Metro            object
# StateCodeFIPS     int64
#                   ...
# 2019-05           int64
# 2019-06           int64
# 2019-07           int64
# 2019-08           int64
# 2019-09           int64
# Length: 289, dtype: object

# %%
#Change MunicipalCodeFIPS dtype to add leading 0's
df_mvsf_nc.loc[ :, 'MunicipalCodeFIPS'] = df_mvsf_nc['MunicipalCodeFIPS'].astype(str)
df_mvsf_nc.dtypes
# Out:
# RegionID          int64
# RegionName       object
# State            object
# Metro            object
# StateCodeFIPS     int64
#                   ...
# 2019-05           int64
# 2019-06           int64
# 2019-07           int64
# 2019-08           int64
# 2019-09           int64
# Length: 289, dtype: object

# %%
#Add leading 0's and check to ensure they were added
df_mvsf_nc.loc[ :, 'MunicipalCodeFIPS'] = df_mvsf_nc['MunicipalCodeFIPS'].str.zfill(3)
df_mvsf_nc.head(5)
# Out:
#      RegionID          RegionName State                       Metro  \
# 48       3102  Mecklenburg County    NC  Charlotte-Concord-Gastonia
# 55        324         Wake County    NC                     Raleigh
# 134      2312     Guilford County    NC       Greensboro-High Point
# 180      1712      Forsyth County    NC               Winston-Salem
# 194      2912   Cumberland County    NC                Fayetteville
#
#      StateCodeFIPS MunicipalCodeFIPS  SizeRank  1996-04  1996-05  1996-06  \
# 48              37               119        49     67.0     67.0     67.0
# 55              37               183        56     78.0     78.0     78.0
# 134             37               081       135     68.0     67.0     65.0
# 180             37               067       181     59.0     59.0     60.0
# 194             37               051       195     53.0     54.0     54.0
#
#      ...  2018-12  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  \
# 48   ...      129      130      131      131      131      131      131
# 55   ...      143      144      145      145      145      145      145
# 134  ...       93       93       94       94       95       95       95
# 180  ...       95       94       95       96       97       98       98
# 194  ...       76       77       77       77       77       77       77
#
#      2019-07  2019-08  2019-09
# 48       131      132      133
# 55       145      146      147
# 134       96       96       96
# 180       98       99      100
# 194       78       78       78
#
# [5 rows x 289 columns]

# %%
# Set Index to Region Name
df_mvsf_nc.set_index(df_mvsf_nc['RegionName'], inplace = True)
df_mvsf_nc

# %%
# Drop Region Name column
df_mvsf_nc.drop('RegionName', axis = 1, inplace = True)
df_mvsf_nc

# %%
#Save to csv file for export in Excel
df_mvsf_nc.to_csv('./Updates/STG_ZLLW_County_MedianValuePerSqft_AllHomes.txt', sep = '\t')
