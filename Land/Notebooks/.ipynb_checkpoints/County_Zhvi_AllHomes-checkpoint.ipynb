# %%
## Written and published by Nathan Young, Junior Data Analyst for NC Data Dashboard, December 2019 ##

# %%
#Imports
import pandas as pd

# %%
# Create Backups
df_backup = pd.read_csv('./Updates/STG_ZLLW_County_Zhvi_AllHomes.txt')
df_backup.to_csv('./Backups/STG_ZLLW_County_Zhvi_AllHomes_BACKUP.txt')

# %%
#Load Land data
df_zhvi = pd.read_csv('http://files.zillowstatic.com/research/public/County/County_Zhvi_AllHomes.csv', 
                      encoding='ISO-8859-1')

#Display table to ensure data loaded correctly
df_zhvi.head()
# Out:
#    RegionID          RegionName State                             Metro  \
# 0      3101  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim
# 1       139         Cook County    IL          Chicago-Naperville-Elgin
# 2      1090       Harris County    TX  Houston-The Woodlands-Sugar Land
# 3      2402     Maricopa County    AZ           Phoenix-Mesa-Scottsdale
# 4      2841    San Diego County    CA                San Diego-Carlsbad
#
#    StateCodeFIPS  MunicipalCodeFIPS  SizeRank   1996-04   1996-05   1996-06  \
# 0              6                 37         1  160800.0  160700.0  160600.0
# 1             17                 31         2  133400.0  134300.0  135000.0
# 2             48                201         3   97900.0   97800.0   97800.0
# 3              4                 13         4  108500.0  108900.0  109300.0
# 4              6                 73         5  163800.0  163400.0  162900.0
#
#    ...  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  2019-07  \
# 0  ...   622000   623200   623200   622700   622700   621800   621300
# 1  ...   224400   225700   226900   226800   225700   224900   224400
# 2  ...   189600   191000   191400   190700   190500   191700   192800
# 3  ...   272100   273400   274200   274600   274700   274600   275300
# 4  ...   592600   592300   592900   593900   593800   593400   593500
#
#    2019-08  2019-09  2019-10
# 0   622900   625400   626600
# 1   224200   224400   224900
# 2   193400   193700   194000
# 3   277200   279300   280500
# 4   593700   594300   596300
#
# [5 rows x 290 columns]

# %%
#Filter data to NC
filter1 = df_zhvi['State'] == "NC"
df_zhvi_nc = df_zhvi[filter1]

#Check to ensure filter worked
df_zhvi_nc.head(5)
# Out:
#      RegionID          RegionName State                       Metro  \
# 48       3102  Mecklenburg County    NC  Charlotte-Concord-Gastonia
# 55        324         Wake County    NC                     Raleigh
# 134      2312     Guilford County    NC       Greensboro-High Point
# 182      1712      Forsyth County    NC               Winston-Salem
# 197      2912   Cumberland County    NC                Fayetteville
#
#      StateCodeFIPS  MunicipalCodeFIPS  SizeRank   1996-04   1996-05   1996-06  \
# 48              37                119        49  119400.0  119700.0  119900.0
# 55              37                183        56  163100.0  162200.0  160900.0
# 134             37                 81       135  106100.0  104000.0  101800.0
# 182             37                 67       183   89100.0   90000.0   90900.0
# 197             37                 51       198   75700.0   75800.0   76100.0
#
#      ...  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  2019-07  \
# 48   ...   240100   241600   242200   242000   241500   241600   242200
# 55   ...   291100   292800   294000   294700   295200   295400   295700
# 134  ...   149500   150600   151400   151700   152200   153300   154700
# 182  ...   144700   145800   147200   148200   148900   149600   150500
# 197  ...   110600   111400   111300   110000   109300   110200   111100
#
#      2019-08  2019-09  2019-10
# 48    243000   244400   246000
# 55    296400   297800   299000
# 134   156400   157500   157600
# 182   151700   153100   153900
# 197   112100   113200   113900
#
# [5 rows x 290 columns]

# %%
#View data types of dataframe
df_zhvi_nc.dtypes
# Out:
# RegionID          int64
# RegionName       object
# State            object
# Metro            object
# StateCodeFIPS     int64
#                   ...
# 2019-06           int64
# 2019-07           int64
# 2019-08           int64
# 2019-09           int64
# 2019-10           int64
# Length: 290, dtype: object

# %%
#Change MunicipalCodeFIPS dtype to add leading 0's
df_zhvi_nc.loc[ :, 'MunicipalCodeFIPS'] = df_zhvi_nc['MunicipalCodeFIPS'].astype(str)
df_zhvi_nc.dtypes
# Out:
# c:\users\natha\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# RegionID          int64
# RegionName       object
# State            object
# Metro            object
# StateCodeFIPS     int64
#                   ...
# 2019-06           int64
# 2019-07           int64
# 2019-08           int64
# 2019-09           int64
# 2019-10           int64
# Length: 290, dtype: object

# %%
#Add leading 0's and check to ensure they were added
df_zhvi_nc.loc[ :, 'MunicipalCodeFIPS'] = df_zhvi_nc['MunicipalCodeFIPS'].str.zfill(3)
df_zhvi_nc.head(5)
# Out:
#      RegionID          RegionName State                       Metro  \
# 48       3102  Mecklenburg County    NC  Charlotte-Concord-Gastonia
# 55        324         Wake County    NC                     Raleigh
# 134      2312     Guilford County    NC       Greensboro-High Point
# 182      1712      Forsyth County    NC               Winston-Salem
# 197      2912   Cumberland County    NC                Fayetteville
#
#      StateCodeFIPS MunicipalCodeFIPS  SizeRank   1996-04   1996-05   1996-06  \
# 48              37               119        49  119400.0  119700.0  119900.0
# 55              37               183        56  163100.0  162200.0  160900.0
# 134             37               081       135  106100.0  104000.0  101800.0
# 182             37               067       183   89100.0   90000.0   90900.0
# 197             37               051       198   75700.0   75800.0   76100.0
#
#      ...  2019-01  2019-02  2019-03  2019-04  2019-05  2019-06  2019-07  \
# 48   ...   240100   241600   242200   242000   241500   241600   242200
# 55   ...   291100   292800   294000   294700   295200   295400   295700
# 134  ...   149500   150600   151400   151700   152200   153300   154700
# 182  ...   144700   145800   147200   148200   148900   149600   150500
# 197  ...   110600   111400   111300   110000   109300   110200   111100
#
#      2019-08  2019-09  2019-10
# 48    243000   244400   246000
# 55    296400   297800   299000
# 134   156400   157500   157600
# 182   151700   153100   153900
# 197   112100   113200   113900
#
# [5 rows x 290 columns]

# %%
# Set Index to Region Name
df_zhvi_nc.set_index(df_zhvi_nc['RegionName'], inplace = True)
df_zhvi_nc.head(5)

# %%
# Drop Region Name column
df_zhvi_nc.drop('RegionName', axis = 1, inplace = True)
df_zhvi_nc.head(5)

# %%
#Save to csv file for export in Excel
df_zhvi_nc.to_csv('./Updates/STG_ZLLW_County_Zhvi_AllHomes.txt', sep = '\t')
