# %%
## Written and published by Nathan Young, Junior Data Analyst for NC Data Dashboard, October 2019 ##

# %%
#Imports
import pandas as pd

# %%
# Create Backups
df_backup = pd.read_csv('./Updates/STG_ZLLW_County_MedianListingPrice_AllHomes.txt')
df_backup.to_csv('./Backups/STG_ZLLW_County_MedianListingPrice_AllHomes_BACKUP.txt')

# %%
#Load Land data
df_mlp = pd.read_csv('http://files.zillowstatic.com/research/public/County/County_MedianListingPrice_AllHomes.csv',
                     encoding='ISO-8859-1')

#Display table to ensure data loaded correctly
df_mlp.head()
# Out:
#            RegionName State                             Metro  StateCodeFIPS  \
# 0  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim              6
# 1         Cook County    IL          Chicago-Naperville-Elgin             17
# 2       Harris County    TX  Houston-The Woodlands-Sugar Land             48
# 3     Maricopa County    AZ           Phoenix-Mesa-Scottsdale              4
# 4    San Diego County    CA                San Diego-Carlsbad              6
#
#    MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 0                 37         1  399000.0  389000.0  399000.0  398880.0  ...
# 1                 31         2  244900.0  249000.0  249000.0  249000.0  ...
# 2                201         3  149900.0  152834.0  154750.0  154900.0  ...
# 3                 13         4  179900.0  175900.0  174900.0  169900.0  ...
# 4                 73         5  399000.0  399000.0  399500.0  399990.0  ...
#
#     2018-12   2019-01   2019-02   2019-03   2019-04   2019-05   2019-06  \
# 0  649999.0  649900.0  650000.0  665000.0  675000.0  679000.0  689000.0
# 1  278850.0  280000.0  289900.0  299000.0  300000.0  300000.0  299900.0
# 2  275000.0  276990.0  278990.0  279900.0  285000.0  283000.0  280000.0
# 3  308787.0  310000.0  310000.0  315000.0  318500.0  318990.0  319900.0
# 4  635000.0  635000.0  639000.0  642900.0  650000.0  659500.0  655000.0
#
#     2019-07   2019-08   2019-09
# 0  695000.0  689000.0  689000.0
# 1  299000.0  292900.0  289999.0
# 2  278290.0  274990.0  274900.0
# 3  317000.0  315000.0  319000.0
# 4  649900.0  650000.0  655900.0
#
# [5 rows x 123 columns]

# %%
#Filter data to NC
filter1 = df_mlp['State'] == "NC"
df_mlp_nc = df_mlp[filter1]

#Check to ensure filter worked
df_mlp_nc.head(5)
# Out:
#              RegionName State                       Metro  StateCodeFIPS  \
# 48   Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# 55          Wake County    NC                     Raleigh             37
# 134     Guilford County    NC       Greensboro-High Point             37
# 183      Forsyth County    NC               Winston-Salem             37
# 198   Cumberland County    NC                Fayetteville             37
#
#      MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 48                 119        49  189900.0  194500.0  190000.0  193900.0  ...
# 55                 183        56  248000.0  245000.0  239900.0  239994.5  ...
# 134                 81       135  159900.0  159900.0  159900.0  159900.0  ...
# 183                 67       184  154900.0  156900.0  159900.0  159900.0  ...
# 198                 51       199       NaN       NaN       NaN       NaN  ...
#
#       2018-12   2019-01   2019-02   2019-03   2019-04   2019-05   2019-06  \
# 48   312990.0  312000.0  318800.0  318000.0  324900.0  321500.0  320000.0
# 55   349900.0  345000.0  345000.0  349000.0  352995.0  350000.0  350000.0
# 134  191650.0  194837.5  196500.0  208000.0  212900.0  214000.0  214000.0
# 183  197000.0  198170.0  201900.0  215000.0  224900.0  219900.0  225000.0
# 198  150000.0  155000.0  163000.0  165450.0  172000.0  169500.0  169000.0
#
#       2019-07   2019-08   2019-09
# 48   318557.0  314900.0  315000.0
# 55   350000.0  350000.0  350165.0
# 134  214900.0  207900.0  209400.0
# 183  227700.0  220000.0  217500.0
# 198  167950.0  169000.0  163000.0
#
# [5 rows x 123 columns]

# %%
#View data types of dataframe
df_mlp_nc.dtypes
# Out:
# RegionName            object
# State                 object
# Metro                 object
# StateCodeFIPS          int64
# MunicipalCodeFIPS      int64
#                       ...
# 2019-05              float64
# 2019-06              float64
# 2019-07              float64
# 2019-08              float64
# 2019-09              float64
# Length: 123, dtype: object

# %%
#Change MunicipalCodeFIPS dtype to add leading 0's
df_mlp_nc.loc[ :, 'MunicipalCodeFIPS'] = df_mlp_nc['MunicipalCodeFIPS'].astype(str)
df_mlp_nc.dtypes
# Out:
# RegionName            object
# State                 object
# Metro                 object
# StateCodeFIPS          int64
# MunicipalCodeFIPS     object
#                       ...
# 2019-05              float64
# 2019-06              float64
# 2019-07              float64
# 2019-08              float64
# 2019-09              float64
# Length: 123, dtype: object

# %%
#Add leading 0's and check to ensure they were added
df_mlp_nc.loc[ :, 'MunicipalCodeFIPS'] = df_mlp_nc['MunicipalCodeFIPS'].str.zfill(3)
df_mlp_nc.head(5)
# Out:
#              RegionName State                       Metro  StateCodeFIPS  \
# 48   Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# 55          Wake County    NC                     Raleigh             37
# 134     Guilford County    NC       Greensboro-High Point             37
# 183      Forsyth County    NC               Winston-Salem             37
# 198   Cumberland County    NC                Fayetteville             37
#
#     MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 48                119        49  189900.0  194500.0  190000.0  193900.0  ...
# 55                183        56  248000.0  245000.0  239900.0  239994.5  ...
# 134               081       135  159900.0  159900.0  159900.0  159900.0  ...
# 183               067       184  154900.0  156900.0  159900.0  159900.0  ...
# 198               051       199       NaN       NaN       NaN       NaN  ...
#
#       2018-12   2019-01   2019-02   2019-03   2019-04   2019-05   2019-06  \
# 48   312990.0  312000.0  318800.0  318000.0  324900.0  321500.0  320000.0
# 55   349900.0  345000.0  345000.0  349000.0  352995.0  350000.0  350000.0
# 134  191650.0  194837.5  196500.0  208000.0  212900.0  214000.0  214000.0
# 183  197000.0  198170.0  201900.0  215000.0  224900.0  219900.0  225000.0
# 198  150000.0  155000.0  163000.0  165450.0  172000.0  169500.0  169000.0
#
#       2019-07   2019-08   2019-09
# 48   318557.0  314900.0  315000.0
# 55   350000.0  350000.0  350165.0
# 134  214900.0  207900.0  209400.0
# 183  227700.0  220000.0  217500.0
# 198  167950.0  169000.0  163000.0
#
# [5 rows x 123 columns]

# %%
#Save to csv file for export in Excel
df_mlp_nc.to_csv('./Updates/STG_ZLLW_County_MedianListingPrice_AllHomes.txt', sep ='\t')
