# %%
import pandas as pd

# %%
df = pd.read_excel('./Data/Land_MeasureDefn.xlsx')
df.head(2)
# Out:
#       Measure_Business_Key Record_Source Measure_Authority Measure_TableID  \
# 0  FRED_HOWNRATEACS0_00000         FRED               FRED    HOWNRATEACS0
# 1          ZLLW_CNTY_ZHVI0         ZLLW               ZLLW            CNTY
#
#   Measure_Table_Line_Number                     Measure_Group_Name  \
# 0                      0000  Homeownership Rate by County (Rate)\n
# 1                     ZHVI0              Zillow County Statistics
#
#                             Measure_Name Measure_Category  \
# 0  Homeownership Rate by County (Rate)\n         Regional
# 1              Zillow House Value Index          Regional
#
#   Observation_Frequency Unit_of_Measure_Code  ...  \
# 0                    YR                RATE   ...
# 1                    MM                INDEX  ...
#
#                                      Source_Citation  Accessed_Date  \
# 0  Source: Federal Reserve Bank of St. Louis: htt...     2019-02-05
# 1  The Zillow House Value Index is a data series ...     2019-12-01
#
#                                              Vintage  Revised_Data_Period  \
# 0             Date Last Updated by FRED is Uncertain                  NaN
# 1  Last updated by Zillow 12/1/19. Uploaded to WN...                  All
#
#        New_Data_Period                                         WNCD_Notes  \
# 0  Dec 30 1899 12:00AM  Downloaded file: GeoFRED_Homeownership_Rate_by...
# 1  Oct  1 2019 12:00AM  Zillow Research Data section on Zillow.com; Co...
#
#   Table_Note_ID Table_Notes Table_Line_Note_ID Table_Line_Notes
# 0           NaN         NaN                NaN              NaN
# 1           NaN         NaN                NaN              NaN
#
# [2 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Measure_Business_Key', 'Record_Source', 'Measure_Authority',
#        'Measure_TableID', 'Measure_Table_Line_Number', 'Measure_Group_Name',
#        'Measure_Name', 'Measure_Category', 'Observation_Frequency',
#        'Unit_of_Measure_Code', 'Unit_of_Measure_Name', 'Default_Scale',
#        'Calculation_Type', 'Measure_Hierarchy_Level', 'Participates_In',
#        'NAICS_Industry_Code_Str', 'BEA_Industry_ID', 'BEA_GDP_Component_ID',
#        'Source_Citation', 'Accessed_Date', 'Vintage', 'Revised_Data_Period',
#        'New_Data_Period', 'WNCD_Notes', 'Table_Note_ID', 'Table_Notes',
#        'Table_Line_Note_ID', 'Table_Line_Notes'],
#       dtype='object')

# %%
df['Accessed_Date']
# Out:
# 0   2019-02-05
# 1   2019-12-01
# 2   2019-12-01
# 3   2019-12-01
# 4   2019-12-01
# 5   2019-02-05
# 6   2019-02-05
# Name: Accessed_Date, dtype: datetime64[ns]

# %%
# library for dates?  Datetime?

# %%
# Set Measure_Business_Key as index
df.set_index(df['Measure_Business_Key'], inplace = True)
df.head(2)
# Out:
#                             Measure_Business_Key Record_Source  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000  FRED_HOWNRATEACS0_00000         FRED
# ZLLW_CNTY_ZHVI0                  ZLLW_CNTY_ZHVI0         ZLLW
#
#                         Measure_Authority Measure_TableID  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000              FRED    HOWNRATEACS0
# ZLLW_CNTY_ZHVI0                      ZLLW            CNTY
#
#                         Measure_Table_Line_Number  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000                      0000
# ZLLW_CNTY_ZHVI0                             ZHVI0
#
#                                             Measure_Group_Name  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000  Homeownership Rate by County (Rate)\n
# ZLLW_CNTY_ZHVI0                      Zillow County Statistics
#
#                                                   Measure_Name  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000  Homeownership Rate by County (Rate)\n
# ZLLW_CNTY_ZHVI0                      Zillow House Value Index
#
#                         Measure_Category Observation_Frequency  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000         Regional                    YR
# ZLLW_CNTY_ZHVI0                 Regional                    MM
#
#                         Unit_of_Measure_Code  ...  \
# Measure_Business_Key                          ...
# FRED_HOWNRATEACS0_00000                RATE   ...
# ZLLW_CNTY_ZHVI0                        INDEX  ...
#
#                                                            Source_Citation  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000  Source: Federal Reserve Bank of St. Louis: htt...
# ZLLW_CNTY_ZHVI0          The Zillow House Value Index is a data series ...
#
#                          Accessed_Date  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000     2019-02-05
# ZLLW_CNTY_ZHVI0             2019-12-01
#
#                                                                    Vintage  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000             Date Last Updated by FRED is Uncertain
# ZLLW_CNTY_ZHVI0          Last updated by Zillow 12/1/19. Uploaded to WN...
#
#                          Revised_Data_Period      New_Data_Period  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000                  NaN  Dec 30 1899 12:00AM
# ZLLW_CNTY_ZHVI0                          All  Oct  1 2019 12:00AM
#
#                                                                 WNCD_Notes  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000  Downloaded file: GeoFRED_Homeownership_Rate_by...
# ZLLW_CNTY_ZHVI0          Zillow Research Data section on Zillow.com; Co...
#
#                         Table_Note_ID Table_Notes Table_Line_Note_ID  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000           NaN         NaN                NaN
# ZLLW_CNTY_ZHVI0                   NaN         NaN                NaN
#
#                         Table_Line_Notes
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000              NaN
# ZLLW_CNTY_ZHVI0                      NaN
#
# [2 rows x 28 columns]

# %%
# Drop Measure_Business_Key column
df.drop('Measure_Business_Key', axis = 1, inplace = True)
df.head(2)
# Out:
#                         Record_Source Measure_Authority Measure_TableID  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000         FRED               FRED    HOWNRATEACS0
# ZLLW_CNTY_ZHVI0                 ZLLW               ZLLW            CNTY
#
#                         Measure_Table_Line_Number  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000                      0000
# ZLLW_CNTY_ZHVI0                             ZHVI0
#
#                                             Measure_Group_Name  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000  Homeownership Rate by County (Rate)\n
# ZLLW_CNTY_ZHVI0                      Zillow County Statistics
#
#                                                   Measure_Name  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000  Homeownership Rate by County (Rate)\n
# ZLLW_CNTY_ZHVI0                      Zillow House Value Index
#
#                         Measure_Category Observation_Frequency  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000         Regional                    YR
# ZLLW_CNTY_ZHVI0                 Regional                    MM
#
#                         Unit_of_Measure_Code Unit_of_Measure_Name  ...  \
# Measure_Business_Key                                               ...
# FRED_HOWNRATEACS0_00000                RATE               Percent  ...
# ZLLW_CNTY_ZHVI0                        INDEX               Points  ...
#
#                                                            Source_Citation  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000  Source: Federal Reserve Bank of St. Louis: htt...
# ZLLW_CNTY_ZHVI0          The Zillow House Value Index is a data series ...
#
#                         Accessed_Date  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000    2019-02-05
# ZLLW_CNTY_ZHVI0            2019-12-01
#
#                                                                    Vintage  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000             Date Last Updated by FRED is Uncertain
# ZLLW_CNTY_ZHVI0          Last updated by Zillow 12/1/19. Uploaded to WN...
#
#                          Revised_Data_Period      New_Data_Period  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000                  NaN  Dec 30 1899 12:00AM
# ZLLW_CNTY_ZHVI0                          All  Oct  1 2019 12:00AM
#
#                                                                 WNCD_Notes  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000  Downloaded file: GeoFRED_Homeownership_Rate_by...
# ZLLW_CNTY_ZHVI0          Zillow Research Data section on Zillow.com; Co...
#
#                         Table_Note_ID Table_Notes Table_Line_Note_ID  \
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000           NaN         NaN                NaN
# ZLLW_CNTY_ZHVI0                   NaN         NaN                NaN
#
#                         Table_Line_Notes
# Measure_Business_Key
# FRED_HOWNRATEACS0_00000              NaN
# ZLLW_CNTY_ZHVI0                      NaN
#
# [2 rows x 27 columns]

# %%
df.to_csv('./Updates/STG_XLSX_MeasureDefn_WRK.txt', sep = '\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-7a14d9c1a3d5> in <module>
# ----> 1 df.to_csv('./Updates/STG_XLSX_MeasureDefn_WRK.txt', sep = '\t')
#
# c:\users\natha\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# c:\users\natha\appdata\local\programs\python\python37\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# c:\users\natha\appdata\local\programs\python\python37\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './Updates/STG_XLSX_MeasureDefn_WRK.txt'
